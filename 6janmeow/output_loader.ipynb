# %%
from pathlib import Path
import pandas as pd

# Path to highlighted outputs folder
OUTPUT_DIR = Path.cwd() / "highlighted_outputs"

# Load all Excel files with suffix _Highlights.xlsx
highlight_files = sorted(OUTPUT_DIR.glob("*_Highlights.xlsx"))

print(f"Found {len(highlight_files)} highlight files:")
for f in highlight_files:
    print(" -", f.name)
# Out:
# Found 6 highlight files:
#  - $A1.Score_Highlights.xlsx
#  - $A1.Score_SigTestTable_Highlights.xlsx
#  - B1_Stance_Highlights.xlsx
#  - B1_Stance_SigTestTable_Highlights.xlsx
#  - S5._Which_category_do_you_fall_under_Highlights.xlsx
#  - S5._Which_category_do_you_fall_under_SigTestTable_Highlights.xlsx

# %%
# Dictionary to store first-row data
first_row_dict = {}

for f in highlight_files:
    try:
        # Read only first row
        df = pd.read_excel(f, nrows=1, engine="openpyxl")

        if df.empty:
            first_row_dict[f.name] = {}
        else:
            # Convert first row to dict: {column_name: value}
            first_row_dict[f.name] = df.iloc[0].to_dict()

    except Exception as e:
        first_row_dict[f.name] = {"ERROR": str(e)}

# Print results clearly
print("First-row values per Highlights file:\n")

for fname, row_data in first_row_dict.items():
    print("=" * 80)
    print(fname)
    if not row_data:
        print("  (No data)")
    else:
        for col, val in row_data.items():
            print(f"  {col}: {val}")
# Out:
# First-row values per Highlights file:
#
# ================================================================================
# $A1.Score_Highlights.xlsx
#   Unnamed: 0: Base
#   Total: 3005.123000000015
#   Total_1: 3005.123000000015
#   Sec: 613.3949999999979
#   JC: 93.0300000000003
#   Poly: 292.7750000000003
#   ITE: 101.7379999999994
#   Local Uni: 483.3933000000018
#   PEI: 177.326900000001
#   NSF: 162.8000000000011
#   Working: 979.664800000007
#   In-Risk: 101
#   Total_2: 3005.123000000015
#   13-14 years: 294.2438999999997
#   15-19 years: 987.0833000000233
#   20-24 years: 1021.321899999996
#   25-29 years: 702.4739000000001
#   Total_3: 3005.123000000015
#   Male: 1429.386399999975
#   Female: 1575.73659999997
#   Total_4: 3005.123000000015
#   Singapore Citizen: 2766.795099999995
#   Singapore Permanent Resident (PR): 238.3279000000007
#   Others: 0
#   Total_5: 3005.123000000015
#   Chinese: 2132.684199999931
#   Malay: 490.1762000000015
#   Indian: 309.1434
#   Others_1: 73.1192
#   Total_6: 3005.123000000015
#   NET Non-working: 1973.458199999957
#   Student: 1950.45819999996
#   Total_7: 3005.123000000015
#   Buddhism: 773.7643000000062
#   Catholicism: 174.2326000000003
#   Christianity: 433.3257999999985
#   Hinduism: 181.8867000000001
#   Islam: 561.8344000000025
#   Sikhism: 9.2273
#   Taoism: 88.98250000000009
#   Others_2: 0
#   Sikhism & Others: 9.2273
#   NET Religion: 2223.253599999931
#   No Religion/Free-thinker: 781.8694000000073
#   Total_8: 1031.664800000008
#   PMET: 617.8719999999997
#   Non-PMET: 413.7927999999984
#   Total_9: 3005.123000000015
#   1-Room HDB: 47.68460000000002
#   2-Room HDB: 100.1850999999999
#   1-Room or 2-Room HDB: 147.8697
#   3-Room HDB: 423.2892999999983
#   4-Room HDB: 993.1359000000018
#   5-Room/ Executive HDB: 804.6578000000023
#   4-Room or 5-Room HDB: 1797.793699999956
#   NET HDB: 2368.95269999993
#   Condo/ Other Apt: 470.1524999999979
#   Bungalow/ Semi-Detached/Terrace: 154.7561000000004
#   Private Flat/Condo/Private House: 624.9086000000016
#   Total_10: 3005.123000000015
#   Yes: 42.34360000000001
#   No: 2962.779400000012
#   Total_11: 42.34360000000001
#   Parents with children 0-9 yrs old: 41.34360000000001
#   Parents with children 10-14 yrs old: 6.167400000000001
#   Parents with children 15-19 yrs old: 1
#   Parents with children 20-24 yrs old: 0
#   25 years old and above: 0
#   Total_12: 3005.123000000015
#   NET at least 1 PDE: 1521.469799999986
#   Did not participate in any PDE: 1483.653199999971
#   Total_13: 3005.123000000015
#   NET Local channels: 1683.100599999953
#   NET Digital & Social Media: 1394.898699999977
#   Total_14: 3005.123000000015
#   I feel that studying is pointless for me: 248.3484000000004
#   I get on badly with the teachers: 141.1685000000001
#   I am content with my life: 2005.162399999939
#   I feel lonely: 268.2008000000001
#   I feel fearful for no apparent reason: 370.5213999999989
#   I've been feeling optimistic about the future: 1803.355399999951
#   I've been dealing well with my problems: 2010.172799999938
#   I act without stopping to think: 340.0787999999991
#   I enjoy new and exciting experiences even if they are unusual: 1672.396999999961
# ================================================================================
# $A1.Score_SigTestTable_Highlights.xlsx
#   _1: nan
#   Total: (A)
#   Total_1: (A)
#   Sec: (B)
#   JC: (C)
#   Poly: (D)
#   ITE: (E)
#   Local Uni: (F)
#   PEI: (G)
#   NSF: (H)
#   Working: (I)
#   In-Risk: (J)
#   Total_2: (A)
#   13-14 years: (B)
#   15-19 years: (C)
#   20-24 years: (D)
#   25-29 years: (E)
#   Total_3: (A)
#   Male: (B)
#   Female: (C)
#   Total_4: (A)
#   Singapore Citizen: (B)
#   Singapore Permanent Resident (PR): (C)
#   Others: (D)
#   Total_5: (A)
#   Chinese: (B)
#   Malay: (C)
#   Indian: (D)
#   Others_1: (E)
#   Total_6: (A)
#   NET Non-working: (B)
#   Student: (C)
#   Total_7: (A)
#   Buddhism: (B)
#   Catholicism: (C)
#   Christianity: (D)
#   Hinduism: (E)
#   Islam: (F)
#   Sikhism: (G)
#   Taoism: (H)
#   Others_2: (I)
#   Sikhism & Others: (J)
#   NET Religion: (K)
#   No Religion/Free-thinker: (L)
#   Total_8: (A)
#   PMET: (B)
#   Non-PMET: (C)
#   Total_9: (A)
#   1-Room HDB: (B)
#   2-Room HDB: (C)
#   1-Room or 2-Room HDB: (D)
#   3-Room HDB: (E)
#   4-Room HDB: (F)
#   5-Room/ Executive HDB: (G)
#   4-Room or 5-Room HDB: (H)
#   NET HDB: (I)
#   Condo/ Other Apt: (J)
#   Bungalow/ Semi-Detached/Terrace: (K)
#   Private Flat/Condo/Private House: (L)
#   Total_10: (A)
#   Yes: (B)
#   No: (C)
#   Total_11: (A)
#   Parents with children 0-9 yrs old: (B)
#   Parents with children 10-14 yrs old: (C)
#   Parents with children 15-19 yrs old: (D)
#   Parents with children 20-24 yrs old: (E)
#   25 years old and above: (F)
#   Total_12: (A)
#   NET at least 1 PDE: (B)
#   Did not participate in any PDE: (C)
#   Total_13: (A)
#   NET Local channels: (B)
#   NET Digital & Social Media: (C)
#   Total_14: (A)
#   I feel that studying is pointless for me: (B)
#   I get on badly with the teachers: (C)
#   I am content with my life: (D)
#   I feel lonely: (E)
#   I feel fearful for no apparent reason: (F)
#   I've been feeling optimistic about the future: (G)
#   I've been dealing well with my problems: (H)
#   I act without stopping to think: (I)
#   I enjoy new and exciting experiences even if they are unusual: (J)
# ================================================================================
# B1_Stance_Highlights.xlsx
#   Unnamed: 0: Base
#   Total: 1498
#   Total_1: 1498
#   30-34 years: 166
#   35-39 years: 163
#   40-44 years: 161
#   45-49 years: 156
#   50-54 years: 159
#   55-59 years: 152
#   60-64 years: 152
#   65-69 years: 136
#   70+ years: 253
#   Total_2: 993
#   Below $1,000: 53
#   $1,000 - $1,999: 109
#   $2,000 - $3,999: 235
#   $4,000 - $5,999: 220
#   $6,000 - $7,999: 129
#   $8,000 - $9,999: 67
#   $10,000 and above: 123
#   Refused: 57
#   Total_3: 1498
#   Male: 716
#   Female: 782
#   Total_4: 1498
#   Singapore Citizen: 1316
#   Singapore Permanent Resident (PR): 182
#   Others: 0
#   Total_5: 1498
#   Chinese: 1149
#   Malay: 176
#   Indian: 128
#   Others_1: 46
#   Total_6: 1498
#   NET Working: 993
#   NET Non-working: 505
#   Student: 0
#   NSF: 0
#   Total_7: 1498
#   Buddhism: 445
#   Catholicism: 77
#   Christianity: 235
#   Hinduism: 87
#   Islam: 203
#   Sikhism: 5
#   Taoism: 116
#   Others_2: 0
#   Sikhism & Others: 5
#   NET Religion: 1168
#   No Religion/Free-thinker: 330
#   Total_8: 993
#   PMET: 682
#   Non-PMET: 311
#   Total_9: 1498
#   1-Room HDB: 26
#   2-Room HDB: 80
#   1-Room or 2-Room HDB: 106
#   3-Room HDB: 264
#   4-Room HDB: 478
#   5-Room/ Executive HDB: 311
#   4-Room or 5-Room HDB: 789
#   NET HDB: 1159
#   Condo/ Other Apt: 203
#   Bungalow/ Semi-Detached/Terrace: 136
#   Private Flat/Condo/Private House: 339
#   Total_10: 1498
#   Yes: 1044
#   No: 454
#   Total_11: 1044
#   Parents with children 0-9 yrs old: 269
#   Parents with children 10-14 yrs old: 209
#   Parents with children 15-19 yrs old: 191
#   Parents with children 20-24 yrs old: 163
#   25 years old and above: 522
#   Total_12: 1498
#   NET at least 1 PDE: 322
#   Did not participate in any PDE: 1176
#   Total_13: 1498
#   NET Local channels: 593
#   NET Digital & Social Media: 335
#   Total_14: 1498
#   I feel that studying is pointless for me: 0
#   I get on badly with the teachers: 0
#   I am content with my life: 1223
#   I feel lonely: 55
#   I feel fearful for no apparent reason: 71
#   I've been feeling optimistic about the future: 1064
#   I've been dealing well with my problems: 1183
#   I act without stopping to think: 110
#   I enjoy new and exciting experiences even if they are unusual: 462
# ================================================================================
# B1_Stance_SigTestTable_Highlights.xlsx
#   _1: nan
#   Total: (A)
#   Total_1: (A)
#   30-34 years: (B)
#   35-39 years: (C)
#   40-44 years: (D)
#   45-49 years: (E)
#   50-54 years: (F)
#   55-59 years: (G)
#   60-64 years: (H)
#   65-69 years: (I)
#   70+ years: (J)
#   Total_2: (A)
#   Below $1,000: (B)
#   $1,000 - $1,999: (C)
#   $2,000 - $3,999: (D)
#   $4,000 - $5,999: (E)
#   $6,000 - $7,999: (F)
#   $8,000 - $9,999: (G)
#   $10,000 and above: (H)
#   Refused: (I)
#   Total_3: (A)
#   Male: (B)
#   Female: (C)
#   Total_4: (A)
#   Singapore Citizen: (B)
#   Singapore Permanent Resident (PR): (C)
#   Others: (D)
#   Total_5: (A)
#   Chinese: (B)
#   Malay: (C)
#   Indian: (D)
#   Others_1: (E)
#   Total_6: (A)
#   NET Working: (B)
#   NET Non-working: (C)
#   Student: (D)
#   NSF: (E)
#   Total_7: (A)
#   Buddhism: (B)
#   Catholicism: (C)
#   Christianity: (D)
#   Hinduism: (E)
#   Islam: (F)
#   Sikhism: (G)
#   Taoism: (H)
#   Others_2: (I)
#   Sikhism & Others: (J)
#   NET Religion: (K)
#   No Religion/Free-thinker: (L)
#   Total_8: (A)
#   PMET: (B)
#   Non-PMET: (C)
#   Total_9: (A)
#   1-Room HDB: (B)
#   2-Room HDB: (C)
#   1-Room or 2-Room HDB: (D)
#   3-Room HDB: (E)
#   4-Room HDB: (F)
#   5-Room/ Executive HDB: (G)
#   4-Room or 5-Room HDB: (H)
#   NET HDB: (I)
#   Condo/ Other Apt: (J)
#   Bungalow/ Semi-Detached/Terrace: (K)
#   Private Flat/Condo/Private House: (L)
#   Total_10: (A)
#   Yes: (B)
#   No: (C)
#   Total_11: (A)
#   Parents with children 0-9 yrs old: (B)
#   Parents with children 10-14 yrs old: (C)
#   Parents with children 15-19 yrs old: (D)
#   Parents with children 20-24 yrs old: (E)
#   25 years old and above: (F)
#   Total_12: (A)
#   NET at least 1 PDE: (B)
#   Did not participate in any PDE: (C)
#   Total_13: (A)
#   NET Local channels: (B)
#   NET Digital & Social Media: (C)
#   Total_14: (A)
#   I feel that studying is pointless for me: (B)
#   I get on badly with the teachers: (C)
#   I am content with my life: (D)
#   I feel lonely: (E)
#   I feel fearful for no apparent reason: (F)
#   I've been feeling optimistic about the future: (G)
#   I've been dealing well with my problems: (H)
#   I act without stopping to think: (I)
#   I enjoy new and exciting experiences even if they are unusual: (J)
# ================================================================================
# S5._Which_category_do_you_fall_under_Highlights.xlsx
#   Unnamed: 0: Base
#   Total: 4805
#   Total_1: 4805
#   Local Youths: 3005
#   Non-Local Youths: 302
#   Adults: 1498
#   Total_2: 4805
#   13 – 14 years: 318
#   15 – 19 years: 1082
#   20 – 24 years: 1157
#   25 – 29 years: 749
#   30 – 34 years: 166
#   35 – 39 years: 163
#   40 – 44 years: 161
#   45 – 49 years: 156
#   50 – 54 years: 159
#   55 – 59 years: 152
#   60 – 64 years: 152
#   65 – 69 years: 136
#   Above 69 years: 253
#   Total_3: 4805
#   Male: 2311
#   Female: 2494
#   Total_4: 4805
#   Singapore Citizen: 4083
#   Singapore Permanent Resident (PR): 420
#   Others: 302
#   Total_5: 4805
#   Chinese: 3282
#   Malay: 666
#   Indian: 437
#   Others_1: 421
#   Total_6: 4805
#   NET Working: 2063
#   NET Non-working: 2742
#   Sec: 658
#   JC: 101
#   Poly: 304
#   ITE: 111
#   Local Uni: 529
#   PEI: 347
#   NET Student: 2051
#   NSF: 164
#   Total_7: 4805
#   In-Risk: 101
#   Total_8: 4805
#   Buddhism: 1284
#   Catholicism: 275
#   Christianity: 698
#   Hinduism: 308
#   Islam: 777
#   Sikhism: 15
#   Taoism: 208
#   Others_2: 1
#   Sikhism & Others: 16
#   NET Religion: 3566
#   No Religion/Free-thinker: 1239
#   Total_9: 2063
#   PMET: 1318
#   Non-PMET: 745
#   Total_10: 2063
#   Below $1,000: 162
#   $1,000 - $1,999: 270
#   $2,000 - $3,999: 655
#   $4,000 - $5,999: 483
#   $6,000 - $7,999: 171
#   $8,000 - $9,999: 82
#   $10,000 and above: 132
#   Refused: 107
#   Total_11: 4805
#   1-Room HDB: 79
#   2-Room HDB: 186
#   1-Room or 2-Room HDB: 265
#   3-Room HDB: 727
#   4-Room HDB: 1528
#   5-Room/ Executive HDB: 1128
#   4-Room or 5-Room HDB: 2656
#   NET HDB: 3648
#   Condo/ Other Apt: 826
#   Bungalow/ Semi-Detached/Terrace: 300
#   Private Flat/Condo/Private House: 1126
#   Total_12: 4805
#   Yes: 1086
#   No: 3719
#   Total_13: 1086
#   Parents with children 0-9 yrs old: 310
#   Parents with children 10-14 yrs old: 215
#   Parents with children 15-19 yrs old: 192
#   Parents with children 20-24 yrs old: 163
#   25 years old and above: 522
#   Total_14: 4805
#   NET at least 1 PDE: 1967
#   Did not participate in any PDE: 2838
#   Total_15: 4805
#   NET Local channels: 2383
#   NET Digital & Social Media: 1849
#   Total_16: 4805
#   I feel that studying is pointless for me: 262
#   I get on badly with the teachers: 154
#   I am content with my life: 3438
#   I feel lonely: 351
#   I feel fearful for no apparent reason: 472
#   I've been feeling optimistic about the future: 3072
#   I've been dealing well with my problems: 3379
#   I act without stopping to think: 488
#   I enjoy new and exciting experiences even if they are unusual: 2265
# ================================================================================
# S5._Which_category_do_you_fall_under_SigTestTable_Highlights.xlsx
#   _1: nan
#   Total: (A)
#   Total_1: (A)
#   Local Youths: (B)
#   Non-Local Youths: (C)
#   Adults: (D)
#   Total_2: (A)
#   13 – 14 years: (B)
#   15 – 19 years: (C)
#   20 – 24 years: (D)
#   25 – 29 years: (E)
#   30 – 34 years: (F)
#   35 – 39 years: (G)
#   40 – 44 years: (H)
#   45 – 49 years: (I)
#   50 – 54 years: (J)
#   55 – 59 years: (K)
#   60 – 64 years: (L)
#   65 – 69 years: (M)
#   Above 69 years: (N)
#   Total_3: (A)
#   Male: (B)
#   Female: (C)
#   Total_4: (A)
#   Singapore Citizen: (B)
#   Singapore Permanent Resident (PR): (C)
#   Others: (D)
#   Total_5: (A)
#   Chinese: (B)
#   Malay: (C)
#   Indian: (D)
#   Others_1: (E)
#   Total_6: (A)
#   NET Working: (B)
#   NET Non-working: (C)
#   Sec: (D)
#   JC: (E)
#   Poly: (F)
#   ITE: (G)
#   Local Uni: (H)
#   PEI: (I)
#   NET Student: (J)
#   NSF: (K)
#   Total_7: (A)
#   In-Risk: (B)
#   Total_8: (A)
#   Buddhism: (B)
#   Catholicism: (C)
#   Christianity: (D)
#   Hinduism: (E)
#   Islam: (F)
#   Sikhism: (G)
#   Taoism: (H)
#   Others_2: (I)
#   Sikhism & Others: (J)
#   NET Religion: (K)
#   No Religion/Free-thinker: (L)
#   Total_9: (A)
#   PMET: (B)
#   Non-PMET: (C)
#   Total_10: (A)
#   Below $1,000: (B)
#   $1,000 - $1,999: (C)
#   $2,000 - $3,999: (D)
#   $4,000 - $5,999: (E)
#   $6,000 - $7,999: (F)
#   $8,000 - $9,999: (G)
#   $10,000 and above: (H)
#   Refused: (I)
#   Total_11: (A)
#   1-Room HDB: (B)
#   2-Room HDB: (C)
#   1-Room or 2-Room HDB: (D)
#   3-Room HDB: (E)
#   4-Room HDB: (F)
#   5-Room/ Executive HDB: (G)
#   4-Room or 5-Room HDB: (H)
#   NET HDB: (I)
#   Condo/ Other Apt: (J)
#   Bungalow/ Semi-Detached/Terrace: (K)
#   Private Flat/Condo/Private House: (L)
#   Total_12: (A)
#   Yes: (B)
#   No: (C)
#   Total_13: (A)
#   Parents with children 0-9 yrs old: (B)
#   Parents with children 10-14 yrs old: (C)
#   Parents with children 15-19 yrs old: (D)
#   Parents with children 20-24 yrs old: (E)
#   25 years old and above: (F)
#   Total_14: (A)
#   NET at least 1 PDE: (B)
#   Did not participate in any PDE: (C)
#   Total_15: (A)
#   NET Local channels: (B)
#   NET Digital & Social Media: (C)
#   Total_16: (A)
#   I feel that studying is pointless for me: (B)
#   I get on badly with the teachers: (C)
#   I am content with my life: (D)
#   I feel lonely: (E)
#   I feel fearful for no apparent reason: (F)
#   I've been feeling optimistic about the future: (G)
#   I've been dealing well with my problems: (H)
#   I act without stopping to think: (I)
#   I enjoy new and exciting experiences even if they are unusual: (J)
